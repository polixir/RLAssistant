# %% [markdown]
# # init

# %%
import os
from RLA.easy_plot.plot_func_v2 import plot_func
import numpy as np

# %% [markdown]
# # config basic info

# %%
data_root = 'test_data_root'
task = 'demo_task'

# %% [markdown]
# # simple plot

# %%
regs = [
    '2022/03/01/21-[12]*'
]
_ = plot_func(data_root=data_root, task_table_name=task, regs=regs, split_keys=['learning_rate'],
              metrics=['perf/mse'])
# customize the figure
# Out:
# searching 2022/03/01/21-[12]*
# skipping progress file in  test_data_root/log/demo_task/2022/03/01/21-19-57-875205 11.0.91.89 &env_id=Test-v1&learning_rate=0.01&seed=888 empty data
# find log number 6
# --- complete process ---

# %% [markdown]
# ## config your figure ( similar to matplotlib API)

# %%
# ylim=(0, 0.1)
regs = [
    '2022/03/01/21-[12]*'
]
_ = plot_func(data_root=data_root, task_table_name=task, regs=regs, split_keys=['learning_rate'],
              metrics=['perf/mse'], ylim=(0, 0.1))
# Out:
# searching 2022/03/01/21-[12]*
# skipping progress file in  test_data_root/log/demo_task/2022/03/01/21-19-57-875205 11.0.91.89 &env_id=Test-v1&learning_rate=0.01&seed=888 empty data
# find log number 6
# --- complete process ---

# %%
# add xlabel='epochs',  ylabel='reward ratio'.
regs = [
    '2022/03/01/21-[12]*'
]
_ = plot_func(data_root=data_root, task_table_name=task, regs=regs, split_keys=['learning_rate'],
              metrics=['perf/mse'], ylim=(0, 0.1),
              xlabel='epochs',  ylabel='reward ratio')
# Out:
# searching 2022/03/01/21-[12]*
# skipping progress file in  test_data_root/log/demo_task/2022/03/01/21-19-57-875205 11.0.91.89 &env_id=Test-v1&learning_rate=0.01&seed=888 empty data
# find log number 6
# --- complete process ---

# %% [markdown]
# ### change the place of legends

# %%
regs = [
    '2022/03/01/21-[12]*'
]
_ = plot_func(data_root=data_root, task_table_name=task, regs=regs, split_keys=['learning_rate'],
              metrics=['perf/mse'], ylim=(0, 0.1), xlabel='epochs',  ylabel='reward ratio', 
              legend_outside=False)
# Out:
# searching 2022/03/01/21-[12]*
# skipping progress file in  test_data_root/log/demo_task/2022/03/01/21-19-57-875205 11.0.91.89 &env_id=Test-v1&learning_rate=0.01&seed=888 empty data
# find log number 6
# --- complete process ---

# %% [markdown]
# ### change colors

# %%
regs = [
    '2022/03/01/21-[12]*'
]

_ = plot_func(data_root=data_root, task_table_name=task, regs=regs, split_keys=['learning_rate'],
              metrics=['perf/mse'], ylim=(0, 0.1), xlabel='epochs',  ylabel='reward ratio', 
              legend_outside=False, colors=['green', 'pink', 'black'])
# Out:
# searching 2022/03/01/21-[12]*
# skipping progress file in  test_data_root/log/demo_task/2022/03/01/21-19-57-875205 11.0.91.89 &env_id=Test-v1&learning_rate=0.01&seed=888 empty data
# find log number 6
# --- complete process ---

# %% [markdown]
# ### use markers

# %%
regs = [
    '2022/03/01/21-[12]*'
]

_ = plot_func(data_root=data_root, task_table_name=task, regs=regs, split_keys=['learning_rate'],
              metrics=['perf/mse'], ylim=(0, 0.1), xlabel='epochs',  ylabel='reward ratio', 
              legend_outside=False, use_marker=True)
# Out:
# searching 2022/03/01/21-[12]*
# skipping progress file in  test_data_root/log/demo_task/2022/03/01/21-19-57-875205 11.0.91.89 &env_id=Test-v1&learning_rate=0.01&seed=888 empty data
# find log number 6
# --- complete process ---

# %%
# add resample for clarity
regs = [
    '2022/03/01/21-[12]*'
]

_ = plot_func(data_root=data_root, task_table_name=task, regs=regs, split_keys=['learning_rate'],
              metrics=['perf/mse'], ylim=(0, 0.1), xlabel='epochs',  ylabel='reward ratio', 
              resample=200,
              legend_outside=False, use_marker=True)
# Out:
# searching 2022/03/01/21-[12]*
# skipping progress file in  test_data_root/log/demo_task/2022/03/01/21-19-57-875205 11.0.91.89 &env_id=Test-v1&learning_rate=0.01&seed=888 empty data
# find log number 6
# --- complete process ---

# %%
# customized markers
regs = [
    '2022/03/01/21-[12]*'
]

_ = plot_func(data_root=data_root, task_table_name=task, regs=regs, split_keys=['learning_rate'],
              metrics=['perf/mse'], ylim=(0, 0.1), xlabel='epochs',  ylabel='reward ratio', 
              resample=200,
              legend_outside=False, use_marker=True, markers=['1', '2', '3'])
# Out:
# searching 2022/03/01/21-[12]*
# skipping progress file in  test_data_root/log/demo_task/2022/03/01/21-19-57-875205 11.0.91.89 &env_id=Test-v1&learning_rate=0.01&seed=888 empty data
# find log number 6
# --- complete process ---

# %% [markdown]
# ## cutomize-legends-name mode

# %% [markdown]
# ### one-to-one map

# %%
# reg-map mode.
regs = [
    '2022/03/01/21-[12]*learning_rate=0.01*',
    '2022/03/01/21-[12]*learning_rate=0.00*',
]
_ = plot_func(data_root=data_root, task_table_name=task, regs=regs, split_keys=['learning_rate'],
              metrics=['perf/mse'],  regs2legends=['lr=0.01', 'lr<=0.001'],
              shaded_range=False, pretty=True)
# Out:
# searching 2022/03/01/21-[12]*learning_rate=0.01*
# skipping progress file in  test_data_root/log/demo_task/2022/03/01/21-19-57-875205 11.0.91.89 &env_id=Test-v1&learning_rate=0.01&seed=888 empty data
# find log number 3
# searching 2022/03/01/21-[12]*learning_rate=0.00*
# find log number 3
# summarize results of ALL
# lr=0.01-err : (0.005 $\pm$ 0.003)
# --- complete process ---

# %% [markdown]
# ###  cutomize legends' name map

# %%
regs = [
    '2022/03/01/21-[12]*'
]

def my_key_to_legend(parse_dict, split_keys, y_name, use_y_name):

    task_split_key = '.'.join(f'{k}={parse_dict[k]}' for k in split_keys)
    task_split_key = task_split_key.replace('learning_rate', 'α')
    return task_split_key

_ = plot_func(data_root=data_root, task_table_name=task, regs=regs, split_keys=['learning_rate'],
              metrics=['perf/mse'],
              key_to_legend_fn=my_key_to_legend,
              shaded_range=False, pretty=True, show_number=False)
# Out:
# searching 2022/03/01/21-[12]*
# skipping progress file in  test_data_root/log/demo_task/2022/03/01/21-19-57-875205 11.0.91.89 &env_id=Test-v1&learning_rate=0.01&seed=888 empty data
# find log number 6
# summarize results of ALL
# α=0.0001-err : (0.022 $\pm$ 0.000)
# summarize results of ALL
# α=0.001-err : (0.003 $\pm$ 0.000)
# summarize results of ALL
# α=0.01-err : (0.001 $\pm$ 0.000)
# --- complete process ---

# %% [markdown]
# # add any post-process to your log data

# %%
regs = [
    '2022/03/01/21-[12]*'
]

_ = plot_func(data_root=data_root, task_table_name=task, regs=regs, split_keys=['learning_rate'],
              metrics=['perf/mse'],
              scale_dict={'perf/mse': lambda x: np.log(x)},
              ylabel='RMSE',
              shaded_range=False, pretty=True, show_number=False)
# Out:
# searching 2022/03/01/21-[12]*
# skipping progress file in  test_data_root/log/demo_task/2022/03/01/21-19-57-875205 11.0.91.89 &env_id=Test-v1&learning_rate=0.01&seed=888 empty data
# find log number 6
# summarize results of ALL
# learning_rate=0.0001-err : (-3.821 $\pm$ 0.000)
# summarize results of ALL
# learning_rate=0.001-err : (-5.929 $\pm$ 0.135)
# summarize results of ALL
# learning_rate=0.01-err : (-6.830 $\pm$ 0.099)
# --- complete process ---

# %% [markdown]
# # multiply metrics plotting

# %%
regs = [
    '2022/11/24/*'
]
_ = plot_func(data_root=data_root, task_table_name=task, regs=regs, split_keys=['learning_rate'],
              metrics=['perf/mse', 'y_out', 'y_out_std', 'y_out_max'])
# Out:
# searching 2022/11/24/*
# find log number 1
# --- complete process ---

# %%
# multiple experiments
regs = [
    '2022/11/24/*',
    '2023/02/02/*',
]
_ = plot_func(data_root=data_root, task_table_name=task, regs=regs, split_keys=['learning_rate'],
              metrics=['perf/mse', 'y_out', 'y_out_std'])
# Out:
# searching 2022/11/24/*
# find log number 1
# searching 2023/02/02/*
# find log number 1
# --- complete process ---

# %% [markdown]
# # pretty mode: plot publishable pictures

# %%
regs = [
    '2022/03/01/21-[12]*'
]

_ = plot_func(data_root=data_root, task_table_name=task, regs=regs, split_keys=['learning_rate'],
              metrics=['perf/mse'], ylim=(-0.005, 0.1), xlabel='epochs',  ylabel='reward ratio',
              shaded_range=False, show_number=False, pretty=True)
# use_marker=True, 
_ = plot_func(data_root=data_root, task_table_name=task, regs=regs, split_keys=['learning_rate'],
              metrics=['perf/mse'], ylim=(-0.005, 0.1), xlabel='epochs',  ylabel='reward ratio',
              use_marker=True, 
              shaded_range=False, show_number=False, pretty=True)

# the results will be saved in data_root/results/easy_plot/save_name.
_ = plot_func(data_root=data_root, task_table_name=task, regs=regs, split_keys=['learning_rate'],
              metrics=['perf/mse'], ylim=(-0.005, 0.1), xlabel='epochs',  ylabel='reward ratio', use_marker=True,
              resample=200,  legend_outside=False, show_number=False, 
              shaded_range=False, pretty=True, save_name='saved_image.pdf')
# Out:
# searching 2022/03/01/21-[12]*
# skipping progress file in  test_data_root/log/demo_task/2022/03/01/21-19-57-875205 11.0.91.89 &env_id=Test-v1&learning_rate=0.01&seed=888 empty data
# find log number 6
# summarize results of ALL
# learning_rate=0.0001-err : (0.022 $\pm$ 0.000)
# summarize results of ALL
# learning_rate=0.001-err : (0.003 $\pm$ 0.000)
# summarize results of ALL
# learning_rate=0.01-err : (0.001 $\pm$ 0.000)
# --- complete process ---
# searching 2022/03/01/21-[12]*
# skipping progress file in  test_data_root/log/demo_task/2022/03/01/21-19-57-875205 11.0.91.89 &env_id=Test-v1&learning_rate=0.01&seed=888 empty data
# find log number 6
# summarize results of ALL
# learning_rate=0.0001-err : (0.022 $\pm$ 0.000)
# summarize results of ALL
# learning_rate=0.001-err : (0.003 $\pm$ 0.000)
# summarize results of ALL
# learning_rate=0.01-err : (0.001 $\pm$ 0.000)
# --- complete process ---
# searching 2022/03/01/21-[12]*
# skipping progress file in  test_data_root/log/demo_task/2022/03/01/21-19-57-875205 11.0.91.89 &env_id=Test-v1&learning_rate=0.01&seed=888 empty data
# find log number 6
# summarize results of ALL
# learning_rate=0.0001-err : (0.023 $\pm$ 0.000)
# summarize results of ALL
# learning_rate=0.001-err : (0.003 $\pm$ 0.000)
# summarize results of ALL
# learning_rate=0.01-err : (0.001 $\pm$ 0.000)
# --- complete process ---
# saved location: test_data_root/results/easy_plot/saved_image.pdf

# %%
# multiple experiments
regs = [
    '2022/11/24/*',
    '2023/02/02/*',
]
_ = plot_func(data_root=data_root, task_table_name=task, regs=regs, split_keys=['learning_rate'],
              metrics=['perf/mse', 'y_out', 'y_out_std'], use_marker=True, resample=100, pretty=True)
# custom_y_labels
_ = plot_func(data_root=data_root, task_table_name=task, regs=regs, split_keys=['learning_rate'],
              metrics=['perf/mse', 'y_out', 'y_out_std'],use_marker=True, resample=100, 
              ylabel=['MSE', 'Y', 'Y std'], pretty=True)
# custom legend ncols
_ = plot_func(data_root=data_root, task_table_name=task, regs=regs, split_keys=['learning_rate'],
              metrics=['perf/mse', 'y_out', 'y_out_std'],use_marker=True, resample=100, 
              ylabel=['MSE', 'Y', 'Y std'], legend_ncol=4, pretty=True)
# custom legend name & save
_ = plot_func(data_root=data_root, task_table_name=task, regs=regs, split_keys=['learning_rate'],
              metrics=['perf/mse', 'y_out', 'y_out_std'],use_marker=True, resample=100, 
              regs2legends=['lr=0.001', 'lr=0.0001'],
              ylabel=['MSE', 'Y', 'Y std'], pretty=True, legend_ncol=4, save_name='multi_plot.pdf')
# Out:
# searching 2022/11/24/*
# find log number 1
# searching 2023/02/02/*
# find log number 1
# summarize results of perf/mse
# learning_rate=0.0001 (1)-err : (0.022 $\pm$ 0.000)
# learning_rate=0.0001 (1)-range : (0.022, 0.022)
# summarize results of y_out
# learning_rate=0.0001 (1)-err : (0.003 $\pm$ 0.000)
# learning_rate=0.0001 (1)-range : (0.003, 0.003)
# summarize results of y_out_std
# learning_rate=0.0001 (1)-err : (0.516 $\pm$ 0.000)
# learning_rate=0.0001 (1)-range : (0.516, 0.516)
# summarize results of perf/mse
# learning_rate=0.001 (1)-err : (0.002 $\pm$ 0.000)
# learning_rate=0.001 (1)-range : (0.002, 0.002)
# summarize results of y_out
# learning_rate=0.001 (1)-err : (0.022 $\pm$ 0.000)
# learning_rate=0.001 (1)-range : (0.022, 0.022)
# summarize results of y_out_std
# learning_rate=0.001 (1)-err : (0.540 $\pm$ 0.000)
# learning_rate=0.001 (1)-range : (0.540, 0.540)
# --- complete process ---
# searching 2022/11/24/*
# find log number 1
# searching 2023/02/02/*
# find log number 1
# summarize results of perf/mse
# learning_rate=0.0001 (1)-err : (0.022 $\pm$ 0.000)
# learning_rate=0.0001 (1)-range : (0.022, 0.022)
# summarize results of y_out
# learning_rate=0.0001 (1)-err : (0.003 $\pm$ 0.000)
# learning_rate=0.0001 (1)-range : (0.003, 0.003)
# summarize results of y_out_std
# learning_rate=0.0001 (1)-err : (0.516 $\pm$ 0.000)
# learning_rate=0.0001 (1)-range : (0.516, 0.516)
# summarize results of perf/mse
# learning_rate=0.001 (1)-err : (0.002 $\pm$ 0.000)
# learning_rate=0.001 (1)-range : (0.002, 0.002)
# summarize results of y_out
# learning_rate=0.001 (1)-err : (0.022 $\pm$ 0.000)
# learning_rate=0.001 (1)-range : (0.022, 0.022)
# summarize results of y_out_std
# learning_rate=0.001 (1)-err : (0.540 $\pm$ 0.000)
# learning_rate=0.001 (1)-range : (0.540, 0.540)
# --- complete process ---
# searching 2022/11/24/*
# find log number 1
# searching 2023/02/02/*
# find log number 1
# summarize results of perf/mse
# learning_rate=0.0001 (1)-err : (0.022 $\pm$ 0.000)
# learning_rate=0.0001 (1)-range : (0.022, 0.022)
# summarize results of y_out
# learning_rate=0.0001 (1)-err : (0.003 $\pm$ 0.000)
# learning_rate=0.0001 (1)-range : (0.003, 0.003)
# summarize results of y_out_std
# learning_rate=0.0001 (1)-err : (0.516 $\pm$ 0.000)
# learning_rate=0.0001 (1)-range : (0.516, 0.516)
# summarize results of perf/mse
# learning_rate=0.001 (1)-err : (0.002 $\pm$ 0.000)
# learning_rate=0.001 (1)-range : (0.002, 0.002)
# summarize results of y_out
# learning_rate=0.001 (1)-err : (0.022 $\pm$ 0.000)
# learning_rate=0.001 (1)-range : (0.022, 0.022)
# summarize results of y_out_std
# learning_rate=0.001 (1)-err : (0.540 $\pm$ 0.000)
# learning_rate=0.001 (1)-range : (0.540, 0.540)
# --- complete process ---
# searching 2022/11/24/*
# find log number 1
# searching 2023/02/02/*
# find log number 1
# summarize results of perf/mse
# lr=0.001-err : (0.012 $\pm$ 0.007)
# lr=0.001-range : (0.002, 0.022)
# summarize results of y_out
# lr=0.001-err : (0.012 $\pm$ 0.007)
# lr=0.001-range : (0.003, 0.022)
# summarize results of y_out_std
# lr=0.001-err : (0.528 $\pm$ 0.008)
# lr=0.001-range : (0.516, 0.540)
# --- complete process ---
# saved location: test_data_root/results/easy_plot/multi_plot.pdf
